# %% [markdown]
# # Import libraries

# %%
# drive access
from google.colab import drive
drive.mount('/content/drive')

# standard library
import numpy as np
import pandas as pd

# for audio
import librosa
from IPython.display import Audio
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # Read the transcription csv

# %%
transcription = pd.read_csv('/content/drive/MyDrive/266/Data/Clean_Data/Arctic/transcription.csv')

transcription.head()
# Out:
#   filename                                      transcription
# 0    a0001    Author of the danger trail, Philip Steels, etc.
# 1    a0002  Not at this particular case, Tom, apologized W...
# 2    a0003  For the twentieth time that evening the two me...
# 3    a0004         Lord, but I'm glad to see you again, Phil.
# 4    a0005                            Will we ever forget it.

# %%
transcription.tail()
# Out:
#      filename                                      transcription
# 1127    b0535                       He read his fragments aloud.
# 1128    b0536                         Typhoid -- did I tell you.
# 1129    b0537                   But she had become an automaton.
# 1130    b0538      At the best, they were necessary accessories.
# 1131    b0539  You were making them talk shop, Ruth charged him.

# %% [markdown]
# # Clean bdl csv

# %%
bdl = pd.read_csv('/content/drive/MyDrive/266/Data/Clean_Data/Arctic/auto_transcription/bdl.csv')

bdl.head()
# Out:
#            filename                                 auto_transcription
# 0  arctic_a0004.wav            LORD BUT I'M GLAD TO SEE YOU AGAIN PHIL
# 1  arctic_a0050.wav  IN SPITE OF THEIR ABSURDITY THE WORDS AFFECTED...
# 2  arctic_a0102.wav                             HE WILL FOLLOW US SOON
# 3  arctic_a0072.wav                          BUT WHO WAS ILEN'S DOUBLE
# 4  arctic_a0124.wav   IT WAS JEAN SINGING SOFTLY OVER BEYOND THE ROCKS

# %%
bdl['emotion'] = 'neutral'

bdl.head()
# Out:
#            filename                                 auto_transcription  \
# 0  arctic_a0004.wav            LORD BUT I'M GLAD TO SEE YOU AGAIN PHIL
# 1  arctic_a0050.wav  IN SPITE OF THEIR ABSURDITY THE WORDS AFFECTED...
# 2  arctic_a0102.wav                             HE WILL FOLLOW US SOON
# 3  arctic_a0072.wav                          BUT WHO WAS ILEN'S DOUBLE
# 4  arctic_a0124.wav   IT WAS JEAN SINGING SOFTLY OVER BEYOND THE ROCKS
#
#    emotion
# 0  neutral
# 1  neutral
# 2  neutral
# 3  neutral
# 4  neutral

# %% [markdown]
# ### Add actor and gender attributes to the total csv

# %%
bdl['actor'] = 'bdl'
bdl['gender'] = 'male'

bdl.head()
# Out:
#            filename                                 auto_transcription  \
# 0  arctic_a0004.wav            LORD BUT I'M GLAD TO SEE YOU AGAIN PHIL
# 1  arctic_a0050.wav  IN SPITE OF THEIR ABSURDITY THE WORDS AFFECTED...
# 2  arctic_a0102.wav                             HE WILL FOLLOW US SOON
# 3  arctic_a0072.wav                          BUT WHO WAS ILEN'S DOUBLE
# 4  arctic_a0124.wav   IT WAS JEAN SINGING SOFTLY OVER BEYOND THE ROCKS
#
#    emotion actor gender
# 0  neutral   bdl   male
# 1  neutral   bdl   male
# 2  neutral   bdl   male
# 3  neutral   bdl   male
# 4  neutral   bdl   male

# %% [markdown]
# ## Get the cleaned filenames

# %%
clean_filenames = []
for each in bdl['filename']:
  clean_filenames.append(each.split('.')[0].split('_')[-1])

assert len(clean_filenames) == len(bdl)

clean_filenames[:5]
# Out:
# ['a0004', 'a0050', 'a0102', 'a0072', 'a0124']

# %%
bdl['clean_filename'] = clean_filenames

bdl.head()
# Out:
#            filename                                 auto_transcription  \
# 0  arctic_a0004.wav            LORD BUT I'M GLAD TO SEE YOU AGAIN PHIL
# 1  arctic_a0050.wav  IN SPITE OF THEIR ABSURDITY THE WORDS AFFECTED...
# 2  arctic_a0102.wav                             HE WILL FOLLOW US SOON
# 3  arctic_a0072.wav                          BUT WHO WAS ILEN'S DOUBLE
# 4  arctic_a0124.wav   IT WAS JEAN SINGING SOFTLY OVER BEYOND THE ROCKS
#
#    emotion actor gender clean_filename
# 0  neutral   bdl   male          a0004
# 1  neutral   bdl   male          a0050
# 2  neutral   bdl   male          a0102
# 3  neutral   bdl   male          a0072
# 4  neutral   bdl   male          a0124

# %% [markdown]
# ## Get the true transcriptions/labels based on cleaned filenames

# %%
labels = []

for row in bdl['clean_filename']:
  labels.append(transcription[transcription['filename'] == row]['transcription'].item())

assert len(labels) == len(bdl)

labels[:5]
# Out:
# ["Lord, but I'm glad to see you again, Phil.",
#  'In spite of their absurdity the words affected Philip curiously.',
#  'He will follow us soon.',
#  "But who was Eileen's double.",
#  'It was Jeanne singing softly over beyond the rocks.']

# %%
bdl['label'] = labels

bdl.head(10)
# Out:
#            filename                                 auto_transcription  \
# 0  arctic_a0004.wav            LORD BUT I'M GLAD TO SEE YOU AGAIN PHIL
# 1  arctic_a0050.wav  IN SPITE OF THEIR ABSURDITY THE WORDS AFFECTED...
# 2  arctic_a0102.wav                             HE WILL FOLLOW US SOON
# 3  arctic_a0072.wav                          BUT WHO WAS ILEN'S DOUBLE
# 4  arctic_a0124.wav   IT WAS JEAN SINGING SOFTLY OVER BEYOND THE ROCKS
# 5  arctic_a0145.wav  I HAVE TO BE CAREFUL OF THEM AS THEY TEAR VERY...
# 6  arctic_a0131.wav  PROVIDENCE HAD DELIVERED HIM THROUGH THE MAILS...
# 7  arctic_a0108.wav  HE WADED INTO THE EDGE OF THE WATER AND BEGAN ...
# 8  arctic_a0106.wav  THE EMOTION WHICH SHE HAD SUPPRESSED BURST FOR...
# 9  arctic_a0148.wav   NOW THESE THINGS HAD BEEN STRUCK DEAD WITHIN HIM
#
#    emotion actor gender clean_filename  \
# 0  neutral   bdl   male          a0004
# 1  neutral   bdl   male          a0050
# 2  neutral   bdl   male          a0102
# 3  neutral   bdl   male          a0072
# 4  neutral   bdl   male          a0124
# 5  neutral   bdl   male          a0145
# 6  neutral   bdl   male          a0131
# 7  neutral   bdl   male          a0108
# 8  neutral   bdl   male          a0106
# 9  neutral   bdl   male          a0148
#
#                                                label
# 0         Lord, but I'm glad to see you again, Phil.
# 1  In spite of their absurdity the words affected...
# 2                            He will follow us soon.
# 3                       But who was Eileen's double.
# 4  It was Jeanne singing softly over beyond the r...
# 5  I have to be careful of them, as they tear ver...
# 6  Providence had delivered him through the maels...
# 7  He waded into the edge of the water and began ...
# 8  The emotion which she had suppressed burst for...
# 9  Now these things had been struck dead within him.

# %% [markdown]
# ## Confirm the first 5 characters of the auto transcription and label matches, or the last 5 characters of the auto transcription and label matches, if neither matches, manually investigate

# %% [markdown]
# ### check the first 5 characters

# %%
front_assertions = []

for i, row in bdl.iterrows():
  if str(row['auto_transcription'])[:5].lower() == str(row['label'])[:5].lower():
    front_assertions.append('Y')
  else:
    front_assertions.append('N')

assert len(front_assertions) == len(bdl)

front_assertions[:5]
# Out:
# ['N', 'Y', 'Y', 'Y', 'Y']

# %%
bdl['front_assertions'] = front_assertions

bdl.head()
# Out:
#            filename                                 auto_transcription  \
# 0  arctic_a0004.wav            LORD BUT I'M GLAD TO SEE YOU AGAIN PHIL
# 1  arctic_a0050.wav  IN SPITE OF THEIR ABSURDITY THE WORDS AFFECTED...
# 2  arctic_a0102.wav                             HE WILL FOLLOW US SOON
# 3  arctic_a0072.wav                          BUT WHO WAS ILEN'S DOUBLE
# 4  arctic_a0124.wav   IT WAS JEAN SINGING SOFTLY OVER BEYOND THE ROCKS
#
#    emotion actor gender clean_filename  \
# 0  neutral   bdl   male          a0004
# 1  neutral   bdl   male          a0050
# 2  neutral   bdl   male          a0102
# 3  neutral   bdl   male          a0072
# 4  neutral   bdl   male          a0124
#
#                                                label front_assertions
# 0         Lord, but I'm glad to see you again, Phil.                N
# 1  In spite of their absurdity the words affected...                Y
# 2                            He will follow us soon.                Y
# 3                       But who was Eileen's double.                Y
# 4  It was Jeanne singing softly over beyond the r...                Y

# %%
bdl['front_assertions'].value_counts()
# Out:
# Y    1023
# N     109
# Name: front_assertions, dtype: int64

# %% [markdown]
# ### check the last 5 characters

# %%
back_assertions = []

for i, row in bdl.iterrows():
  if str(row['auto_transcription'])[-5:].lower() == str(row['label']).replace('.','')[-5:].lower():
      back_assertions.append('Y')
  else:
    back_assertions.append('N')

assert len(back_assertions) == len(bdl)

back_assertions[:5]
# Out:
# ['Y', 'Y', 'Y', 'Y', 'Y']

# %%
bdl['back_assertions'] = back_assertions

bdl.head()
# Out:
#            filename                                 auto_transcription  \
# 0  arctic_a0004.wav            LORD BUT I'M GLAD TO SEE YOU AGAIN PHIL
# 1  arctic_a0050.wav  IN SPITE OF THEIR ABSURDITY THE WORDS AFFECTED...
# 2  arctic_a0102.wav                             HE WILL FOLLOW US SOON
# 3  arctic_a0072.wav                          BUT WHO WAS ILEN'S DOUBLE
# 4  arctic_a0124.wav   IT WAS JEAN SINGING SOFTLY OVER BEYOND THE ROCKS
#
#    emotion actor gender clean_filename  \
# 0  neutral   bdl   male          a0004
# 1  neutral   bdl   male          a0050
# 2  neutral   bdl   male          a0102
# 3  neutral   bdl   male          a0072
# 4  neutral   bdl   male          a0124
#
#                                                label front_assertions  \
# 0         Lord, but I'm glad to see you again, Phil.                N
# 1  In spite of their absurdity the words affected...                Y
# 2                            He will follow us soon.                Y
# 3                       But who was Eileen's double.                Y
# 4  It was Jeanne singing softly over beyond the r...                Y
#
#   back_assertions
# 0               Y
# 1               Y
# 2               Y
# 3               Y
# 4               Y

# %%
bdl['back_assertions'].value_counts()
# Out:
# Y    1064
# N      68
# Name: back_assertions, dtype: int64

# %% [markdown]
# ### manually check instances where either front and back assertions failed

# %%
bdl[(bdl['front_assertions'] == 'N') | (bdl['back_assertions'] == 'N')]
# Out:
#               filename                                 auto_transcription  \
# 0     arctic_a0004.wav            LORD BUT I'M GLAD TO SEE YOU AGAIN PHIL
# 6     arctic_a0131.wav  PROVIDENCE HAD DELIVERED HIM THROUGH THE MAILS...
# 11    arctic_a0063.wav              YES IT WAS A MAN WHO ASKED A STRANGER
# 31    arctic_a0234.wav  WHY THE AVERAGE REVIEW IS MORE NAUSEATING THAN...
# 32    arctic_a0245.wav  OUT OF HIS EIGHTEEN HUNDRED HE LAID ASIDE SIXT...
# ...                ...                                                ...
# 1103  arctic_a0138.wav  IN THE PICTURE HE SAW EACH MOMENT A GREATER RE...
# 1111  arctic_a0153.wav  MCDUGALL TAPPED HIS FOREHEAD SUSPICIOUSLY WITH...
# 1118  arctic_a0140.wav        EXCEPT A FATHER'S BLESSING AND WITH IT THIS
# 1121  arctic_a0006.wav  GOD BLESS HIM I HOPE I'LL GO ON SEEING THEM FO...
# 1129  arctic_a0001.wav  AUTHOR OF THE DANGER TRAIL PHILIP STEALS ET CE...
#
#       emotion actor gender clean_filename  \
# 0     neutral   bdl   male          a0004
# 6     neutral   bdl   male          a0131
# 11    neutral   bdl   male          a0063
# 31    neutral   bdl   male          a0234
# 32    neutral   bdl   male          a0245
# ...       ...   ...    ...            ...
# 1103  neutral   bdl   male          a0138
# 1111  neutral   bdl   male          a0153
# 1118  neutral   bdl   male          a0140
# 1121  neutral   bdl   male          a0006
# 1129  neutral   bdl   male          a0001
#
#                                                   label front_assertions  \
# 0            Lord, but I'm glad to see you again, Phil.                N
# 6     Providence had delivered him through the maels...                Y
# 11             Yes, it was a man who asked, a stranger.                N
# 31    Why, the average review is more nauseating tha...                N
# 32    Out of his eighteen hundred, he laid aside six...                Y
# ...                                                 ...              ...
# 1103  In the picture he saw each moment a greater re...                Y
# 1111  MacDougall tapped his forehead suspiciously wi...                N
# 1118     Accept a father's blessing, and with it, this.                N
# 1121  God bless 'em, I hope I'll go on seeing them f...                Y
# 1129    Author of the danger trail, Philip Steels, etc.                Y
#
#      back_assertions
# 0                  Y
# 6                  N
# 11                 Y
# 31                 Y
# 32                 N
# ...              ...
# 1103               N
# 1111               Y
# 1118               Y
# 1121               N
# 1129               N
#
# [165 rows x 9 columns]

# %% [markdown]
# Manually checked instances where either the front or the back assertions failed, confirmed no mis-matched instances

# %% [markdown]
# # Export the cleaned bdl csv to be merged to the main csv

# %%
bdl.drop(columns=['front_assertions', 'back_assertions'], inplace=True)

bdl.head()
# Out:
#            filename                                 auto_transcription  \
# 0  arctic_a0004.wav            LORD BUT I'M GLAD TO SEE YOU AGAIN PHIL
# 1  arctic_a0050.wav  IN SPITE OF THEIR ABSURDITY THE WORDS AFFECTED...
# 2  arctic_a0102.wav                             HE WILL FOLLOW US SOON
# 3  arctic_a0072.wav                          BUT WHO WAS ILEN'S DOUBLE
# 4  arctic_a0124.wav   IT WAS JEAN SINGING SOFTLY OVER BEYOND THE ROCKS
#
#    emotion actor gender clean_filename  \
# 0  neutral   bdl   male          a0004
# 1  neutral   bdl   male          a0050
# 2  neutral   bdl   male          a0102
# 3  neutral   bdl   male          a0072
# 4  neutral   bdl   male          a0124
#
#                                                label
# 0         Lord, but I'm glad to see you again, Phil.
# 1  In spite of their absurdity the words affected...
# 2                            He will follow us soon.
# 3                       But who was Eileen's double.
# 4  It was Jeanne singing softly over beyond the r...

# %%
bdl.to_csv('/content/drive/MyDrive/266/Data/Clean_Data/Arctic/bdl.csv', index=False)
