# %% [markdown]
# # Import libraries

# %%
# drive access
from google.colab import drive
drive.mount('/content/drive')

# standard library
import numpy as np
import pandas as pd

# for audio
import librosa
from IPython.display import Audio
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Read the transcription csv

# %%
transcription = pd.read_csv('/content/drive/MyDrive/266/Data/Clean_Data/Arctic/transcription.csv')

transcription.head()
# Out:
#   filename                                      transcription
# 0    a0001    Author of the danger trail, Philip Steels, etc.
# 1    a0002  Not at this particular case, Tom, apologized W...
# 2    a0003  For the twentieth time that evening the two me...
# 3    a0004         Lord, but I'm glad to see you again, Phil.
# 4    a0005                            Will we ever forget it.

# %%
transcription.tail()
# Out:
#      filename                                      transcription
# 1127    b0535                       He read his fragments aloud.
# 1128    b0536                         Typhoid -- did I tell you.
# 1129    b0537                   But she had become an automaton.
# 1130    b0538      At the best, they were necessary accessories.
# 1131    b0539  You were making them talk shop, Ruth charged him.

# %% [markdown]
# # Clean slt csv

# %%
slt = pd.read_csv('/content/drive/MyDrive/266/Data/Clean_Data/Arctic/auto_transcription/slt.csv')

slt.head()
# Out:
#            filename                                 auto_transcription
# 0  arctic_b0218.wav                         THE ISSUE WAS NOT IN DOUBT
# 1  arctic_a0532.wav                     MAY DROUGHT DESTROY YOUR CROPS
# 2  arctic_b0203.wav               A MONTH IN AUSTRALIA WOULD FINISH ME
# 3  arctic_a0562.wav                                   WHAT THE FLAMING
# 4  arctic_a0308.wav  HIS INFERNAL CHATTERING WORRIES ME EVEN NOW AS...

# %%
slt['emotion'] = 'neutral'

slt.head()
# Out:
#            filename                                 auto_transcription  \
# 0  arctic_b0218.wav                         THE ISSUE WAS NOT IN DOUBT
# 1  arctic_a0532.wav                     MAY DROUGHT DESTROY YOUR CROPS
# 2  arctic_b0203.wav               A MONTH IN AUSTRALIA WOULD FINISH ME
# 3  arctic_a0562.wav                                   WHAT THE FLAMING
# 4  arctic_a0308.wav  HIS INFERNAL CHATTERING WORRIES ME EVEN NOW AS...
#
#    emotion
# 0  neutral
# 1  neutral
# 2  neutral
# 3  neutral
# 4  neutral

# %% [markdown]
# ### Add actor and gender attributes to the total csv

# %%
slt['actor'] = 'slt'
slt['gender'] = 'female'

slt.head()
# Out:
#            filename                                 auto_transcription  \
# 0  arctic_b0218.wav                         THE ISSUE WAS NOT IN DOUBT
# 1  arctic_a0532.wav                     MAY DROUGHT DESTROY YOUR CROPS
# 2  arctic_b0203.wav               A MONTH IN AUSTRALIA WOULD FINISH ME
# 3  arctic_a0562.wav                                   WHAT THE FLAMING
# 4  arctic_a0308.wav  HIS INFERNAL CHATTERING WORRIES ME EVEN NOW AS...
#
#    emotion actor  gender
# 0  neutral   slt  female
# 1  neutral   slt  female
# 2  neutral   slt  female
# 3  neutral   slt  female
# 4  neutral   slt  female

# %% [markdown]
# ## Get the cleaned filenames

# %%
clean_filenames = []
for each in slt['filename']:
  clean_filenames.append(each.split('.')[0].split('_')[-1])

assert len(clean_filenames) == len(slt)

clean_filenames[:5]
# Out:
# ['b0218', 'a0532', 'b0203', 'a0562', 'a0308']

# %%
slt['clean_filename'] = clean_filenames

slt.head()
# Out:
#            filename                                 auto_transcription  \
# 0  arctic_b0218.wav                         THE ISSUE WAS NOT IN DOUBT
# 1  arctic_a0532.wav                     MAY DROUGHT DESTROY YOUR CROPS
# 2  arctic_b0203.wav               A MONTH IN AUSTRALIA WOULD FINISH ME
# 3  arctic_a0562.wav                                   WHAT THE FLAMING
# 4  arctic_a0308.wav  HIS INFERNAL CHATTERING WORRIES ME EVEN NOW AS...
#
#    emotion actor  gender clean_filename
# 0  neutral   slt  female          b0218
# 1  neutral   slt  female          a0532
# 2  neutral   slt  female          b0203
# 3  neutral   slt  female          a0562
# 4  neutral   slt  female          a0308

# %% [markdown]
# ## Get the true transcriptions/labels based on cleaned filenames

# %%
labels = []

for row in slt['clean_filename']:
  labels.append(transcription[transcription['filename'] == row]['transcription'].item())

assert len(labels) == len(slt)

labels[:5]
# Out:
# ['The issue was not in doubt.',
#  'May drought destroy your crops.',
#  'A month in Australia would finish me.',
#  'What the flaming.',
#  'His infernal chattering worries me even now as I think of it.']

# %%
slt['label'] = labels

slt.head(10)
# Out:
#            filename                                 auto_transcription  \
# 0  arctic_b0218.wav                         THE ISSUE WAS NOT IN DOUBT
# 1  arctic_a0532.wav                     MAY DROUGHT DESTROY YOUR CROPS
# 2  arctic_b0203.wav               A MONTH IN AUSTRALIA WOULD FINISH ME
# 3  arctic_a0562.wav                                   WHAT THE FLAMING
# 4  arctic_a0308.wav  HIS INFERNAL CHATTERING WORRIES ME EVEN NOW AS...
# 5  arctic_b0273.wav          THEN IT WAS THAT A STRANGE THING HAPPENED
# 6  arctic_a0128.wav  THIS ONE HOPE WAS DESTROYED AS QUICKLY AS IT W...
# 7  arctic_a0292.wav  HERE IN THE MID MORNING THE FIRST CASUALTY OCC...
# 8  arctic_a0285.wav  BUT WHAT THEY WANT WITH YOUR TOOTH BRUSH IS MO...
# 9  arctic_a0485.wav        EACH INSULT ADDED TO THE VALUE OF THE CLAIM
#
#    emotion actor  gender clean_filename  \
# 0  neutral   slt  female          b0218
# 1  neutral   slt  female          a0532
# 2  neutral   slt  female          b0203
# 3  neutral   slt  female          a0562
# 4  neutral   slt  female          a0308
# 5  neutral   slt  female          b0273
# 6  neutral   slt  female          a0128
# 7  neutral   slt  female          a0292
# 8  neutral   slt  female          a0285
# 9  neutral   slt  female          a0485
#
#                                                label
# 0                        The issue was not in doubt.
# 1                    May drought destroy your crops.
# 2              A month in Australia would finish me.
# 3                                  What the flaming.
# 4  His infernal chattering worries me even now as...
# 5         Then it was that a strange thing happened.
# 6  This one hope was destroyed as quickly as it w...
# 7  Here, in the midmorning, the first casualty oc...
# 8  But what they want with your toothbrush is mor...
# 9       Each insult added to the value of the claim.

# %% [markdown]
# ## Confirm the first 5 characters of the auto transcription and label matches, or the last 5 characters of the auto transcription and label matches, if neither matches, manually investigate

# %% [markdown]
# ### check the first 5 characters

# %%
front_assertions = []

for i, row in slt.iterrows():
  if str(row['auto_transcription'])[:5].lower() == str(row['label'])[:5].lower():
    front_assertions.append('Y')
  else:
    front_assertions.append('N')

assert len(front_assertions) == len(slt)

front_assertions[:5]
# Out:
# ['Y', 'Y', 'Y', 'Y', 'Y']

# %%
slt['front_assertions'] = front_assertions

slt.head()
# Out:
#            filename                                 auto_transcription  \
# 0  arctic_b0218.wav                         THE ISSUE WAS NOT IN DOUBT
# 1  arctic_a0532.wav                     MAY DROUGHT DESTROY YOUR CROPS
# 2  arctic_b0203.wav               A MONTH IN AUSTRALIA WOULD FINISH ME
# 3  arctic_a0562.wav                                   WHAT THE FLAMING
# 4  arctic_a0308.wav  HIS INFERNAL CHATTERING WORRIES ME EVEN NOW AS...
#
#    emotion actor  gender clean_filename  \
# 0  neutral   slt  female          b0218
# 1  neutral   slt  female          a0532
# 2  neutral   slt  female          b0203
# 3  neutral   slt  female          a0562
# 4  neutral   slt  female          a0308
#
#                                                label front_assertions
# 0                        The issue was not in doubt.                Y
# 1                    May drought destroy your crops.                Y
# 2              A month in Australia would finish me.                Y
# 3                                  What the flaming.                Y
# 4  His infernal chattering worries me even now as...                Y

# %%
slt['front_assertions'].value_counts()
# Out:
# Y    1044
# N      88
# Name: front_assertions, dtype: int64

# %% [markdown]
# ### check the last 5 characters

# %%
back_assertions = []

for i, row in slt.iterrows():
  if str(row['auto_transcription'])[-5:].lower() == str(row['label']).replace('.','')[-5:].lower():
      back_assertions.append('Y')
  else:
    back_assertions.append('N')

assert len(back_assertions) == len(slt)

back_assertions[:5]
# Out:
# ['Y', 'Y', 'Y', 'Y', 'Y']

# %%
slt['back_assertions'] = back_assertions

slt.head()
# Out:
#            filename                                 auto_transcription  \
# 0  arctic_b0218.wav                         THE ISSUE WAS NOT IN DOUBT
# 1  arctic_a0532.wav                     MAY DROUGHT DESTROY YOUR CROPS
# 2  arctic_b0203.wav               A MONTH IN AUSTRALIA WOULD FINISH ME
# 3  arctic_a0562.wav                                   WHAT THE FLAMING
# 4  arctic_a0308.wav  HIS INFERNAL CHATTERING WORRIES ME EVEN NOW AS...
#
#    emotion actor  gender clean_filename  \
# 0  neutral   slt  female          b0218
# 1  neutral   slt  female          a0532
# 2  neutral   slt  female          b0203
# 3  neutral   slt  female          a0562
# 4  neutral   slt  female          a0308
#
#                                                label front_assertions  \
# 0                        The issue was not in doubt.                Y
# 1                    May drought destroy your crops.                Y
# 2              A month in Australia would finish me.                Y
# 3                                  What the flaming.                Y
# 4  His infernal chattering worries me even now as...                Y
#
#   back_assertions
# 0               Y
# 1               Y
# 2               Y
# 3               Y
# 4               Y

# %%
slt['back_assertions'].value_counts()
# Out:
# Y    1072
# N      60
# Name: back_assertions, dtype: int64

# %% [markdown]
# ### manually check instances where either front and back assertions failed

# %%
slt[(slt['front_assertions'] == 'N') | (slt['back_assertions'] == 'N')]
# Out:
#               filename                                 auto_transcription  \
# 7     arctic_a0292.wav  HERE IN THE MID MORNING THE FIRST CASUALTY OCC...
# 12    arctic_a0502.wav  ANYTHING UNUSUAL OR ABNORMAL WAS SUFFICIENT TO...
# 13    arctic_a0223.wav              MY I'M ALMOST HOMESICK FOR IT ALREADY
# 16    arctic_a0506.wav  THE KLAWDIN WAS LEAVING NEXT MORNING FOR HANNA...
# 18    arctic_a0215.wav                             THEY DIE OUT OF SPIGHT
# ...                ...                                                ...
# 1069  arctic_a0566.wav  DENON'S HANDS WERE RELEASED LONG ENOUGH FOR HI...
# 1084  arctic_a0119.wav                 JANE WAS TURNING THE BOW SHOREWARD
# 1096  arctic_b0236.wav  ULANG WAS TWO HUNDRED AND FIFTY MILES FROM THE...
# 1119  arctic_a0387.wav  BOB GROWING DISGUSTED TURNED BACK SUDDENLY AND...
# 1131  arctic_a0277.wav  MC COY FOUND A STIFLING POISONOUS ATMOSPHERE I...
#
#       emotion actor  gender clean_filename  \
# 7     neutral   slt  female          a0292
# 12    neutral   slt  female          a0502
# 13    neutral   slt  female          a0223
# 16    neutral   slt  female          a0506
# 18    neutral   slt  female          a0215
# ...       ...   ...     ...            ...
# 1069  neutral   slt  female          a0566
# 1084  neutral   slt  female          a0119
# 1096  neutral   slt  female          b0236
# 1119  neutral   slt  female          a0387
# 1131  neutral   slt  female          a0277
#
#                                                   label front_assertions  \
# 7     Here, in the midmorning, the first casualty oc...                N
# 12    Anything unusual or abnormal was sufficient to...                Y
# 13              My, I'm almost homesick for it already.                N
# 16    The Claudine was leaving next morning for Hono...                N
# 18                               They die out of spite.                Y
# ...                                                 ...              ...
# 1069  Dennin's hands were released long enough for h...                N
# 1084              Jeanne was turning the bow shoreward.                N
# 1096  Oolong was two hundred and fifty miles from th...                N
# 1119  Bob, growing disgusted, turned back suddenly a...                N
# 1131  McCoy found a stifling, poisonous atmosphere i...                N
#
#      back_assertions
# 7                  Y
# 12                 N
# 13                 Y
# 16                 N
# 18                 N
# ...              ...
# 1069               Y
# 1084               Y
# 1096               Y
# 1119               Y
# 1131               Y
#
# [142 rows x 9 columns]

# %% [markdown]
# Manually checked instances where either the front or the back assertions failed, confirmed no mis-matched instances

# %% [markdown]
# # Export the cleaned slt csv to be merged to the main csv

# %%
slt.drop(columns=['front_assertions', 'back_assertions'], inplace=True)

slt.head()
# Out:
#            filename                                 auto_transcription  \
# 0  arctic_b0218.wav                         THE ISSUE WAS NOT IN DOUBT
# 1  arctic_a0532.wav                     MAY DROUGHT DESTROY YOUR CROPS
# 2  arctic_b0203.wav               A MONTH IN AUSTRALIA WOULD FINISH ME
# 3  arctic_a0562.wav                                   WHAT THE FLAMING
# 4  arctic_a0308.wav  HIS INFERNAL CHATTERING WORRIES ME EVEN NOW AS...
#
#    emotion actor  gender clean_filename  \
# 0  neutral   slt  female          b0218
# 1  neutral   slt  female          a0532
# 2  neutral   slt  female          b0203
# 3  neutral   slt  female          a0562
# 4  neutral   slt  female          a0308
#
#                                                label
# 0                        The issue was not in doubt.
# 1                    May drought destroy your crops.
# 2              A month in Australia would finish me.
# 3                                  What the flaming.
# 4  His infernal chattering worries me even now as...

# %%
slt.to_csv('/content/drive/MyDrive/266/Data/Clean_Data/Arctic/slt.csv', index=False)
