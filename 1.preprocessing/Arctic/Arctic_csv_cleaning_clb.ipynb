# %% [markdown]
# # Import libraries

# %%
# drive access
from google.colab import drive
drive.mount('/content/drive')

# standard library
import numpy as np
import pandas as pd

# for audio
import librosa
from IPython.display import Audio
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Read the transcription csv

# %%
transcription = pd.read_csv('/content/drive/MyDrive/266/Data/Clean_Data/Arctic/transcription.csv')

transcription.head()
# Out:
#   filename                                      transcription
# 0    a0001    Author of the danger trail, Philip Steels, etc.
# 1    a0002  Not at this particular case, Tom, apologized W...
# 2    a0003  For the twentieth time that evening the two me...
# 3    a0004         Lord, but I'm glad to see you again, Phil.
# 4    a0005                            Will we ever forget it.

# %%
transcription.tail()
# Out:
#      filename                                      transcription
# 1127    b0535                       He read his fragments aloud.
# 1128    b0536                         Typhoid -- did I tell you.
# 1129    b0537                   But she had become an automaton.
# 1130    b0538      At the best, they were necessary accessories.
# 1131    b0539  You were making them talk shop, Ruth charged him.

# %% [markdown]
# # Clean clb csv

# %%
clb = pd.read_csv('/content/drive/MyDrive/266/Data/Clean_Data/Arctic/auto_transcription/clb.csv')

clb.head()
# Out:
#            filename                                 auto_transcription
# 0  arctic_a0133.wav  PHILIP BEGAN TO FEEL THAT HE HAD FOOLISHLY OVE...
# 1  arctic_a0132.wav             A CRY OF JOY BURST FROM PHILLIP'S LIPS
# 2  arctic_a0136.wav  ABOUT HIM EVERYWHERE WERE THE EVIDENCES OF LUX...
# 3  arctic_a0137.wav    THEN HE STEPPED BACK WITH A LOW CRY OF PLEASURE
# 4  arctic_a0135.wav  I AM GOING TO SURPRISE FATHER AND YOU WILL GO ...

# %%
clb['emotion'] = 'neutral'

clb.head()
# Out:
#            filename                                 auto_transcription  \
# 0  arctic_a0133.wav  PHILIP BEGAN TO FEEL THAT HE HAD FOOLISHLY OVE...
# 1  arctic_a0132.wav             A CRY OF JOY BURST FROM PHILLIP'S LIPS
# 2  arctic_a0136.wav  ABOUT HIM EVERYWHERE WERE THE EVIDENCES OF LUX...
# 3  arctic_a0137.wav    THEN HE STEPPED BACK WITH A LOW CRY OF PLEASURE
# 4  arctic_a0135.wav  I AM GOING TO SURPRISE FATHER AND YOU WILL GO ...
#
#    emotion
# 0  neutral
# 1  neutral
# 2  neutral
# 3  neutral
# 4  neutral

# %% [markdown]
# ### Add actor and gender attributes to the total csv

# %%
clb['actor'] = 'clb'
clb['gender'] = 'female'

clb.head()
# Out:
#            filename                                 auto_transcription  \
# 0  arctic_a0133.wav  PHILIP BEGAN TO FEEL THAT HE HAD FOOLISHLY OVE...
# 1  arctic_a0132.wav             A CRY OF JOY BURST FROM PHILLIP'S LIPS
# 2  arctic_a0136.wav  ABOUT HIM EVERYWHERE WERE THE EVIDENCES OF LUX...
# 3  arctic_a0137.wav    THEN HE STEPPED BACK WITH A LOW CRY OF PLEASURE
# 4  arctic_a0135.wav  I AM GOING TO SURPRISE FATHER AND YOU WILL GO ...
#
#    emotion actor  gender
# 0  neutral   clb  female
# 1  neutral   clb  female
# 2  neutral   clb  female
# 3  neutral   clb  female
# 4  neutral   clb  female

# %% [markdown]
# ## Get the cleaned filenames

# %%
clean_filenames = []
for each in clb['filename']:
  clean_filenames.append(each.split('.')[0].split('_')[-1])

assert len(clean_filenames) == len(clb)

clean_filenames[:5]
# Out:
# ['a0133', 'a0132', 'a0136', 'a0137', 'a0135']

# %%
clb['clean_filename'] = clean_filenames

clb.head()
# Out:
#            filename                                 auto_transcription  \
# 0  arctic_a0133.wav  PHILIP BEGAN TO FEEL THAT HE HAD FOOLISHLY OVE...
# 1  arctic_a0132.wav             A CRY OF JOY BURST FROM PHILLIP'S LIPS
# 2  arctic_a0136.wav  ABOUT HIM EVERYWHERE WERE THE EVIDENCES OF LUX...
# 3  arctic_a0137.wav    THEN HE STEPPED BACK WITH A LOW CRY OF PLEASURE
# 4  arctic_a0135.wav  I AM GOING TO SURPRISE FATHER AND YOU WILL GO ...
#
#    emotion actor  gender clean_filename
# 0  neutral   clb  female          a0133
# 1  neutral   clb  female          a0132
# 2  neutral   clb  female          a0136
# 3  neutral   clb  female          a0137
# 4  neutral   clb  female          a0135

# %% [markdown]
# ## Get the true transcriptions/labels based on cleaned filenames

# %%
labels = []

for row in clb['clean_filename']:
  labels.append(transcription[transcription['filename'] == row]['transcription'].item())

assert len(labels) == len(clb)

labels[:5]
# Out:
# ['Philip began to feel that he had foolishly overestimated his strength.',
#  "A cry of joy burst from Philip's lips.",
#  'About him, everywhere, were the evidences of luxury and of age.',
#  'Then he stepped back with a low cry of pleasure.',
#  'I am going to surprise father, and you will go with Pierre.']

# %%
clb['label'] = labels

clb.head(10)
# Out:
#            filename                                 auto_transcription  \
# 0  arctic_a0133.wav  PHILIP BEGAN TO FEEL THAT HE HAD FOOLISHLY OVE...
# 1  arctic_a0132.wav             A CRY OF JOY BURST FROM PHILLIP'S LIPS
# 2  arctic_a0136.wav  ABOUT HIM EVERYWHERE WERE THE EVIDENCES OF LUX...
# 3  arctic_a0137.wav    THEN HE STEPPED BACK WITH A LOW CRY OF PLEASURE
# 4  arctic_a0135.wav  I AM GOING TO SURPRISE FATHER AND YOU WILL GO ...
# 5  arctic_a0138.wav  IN THE PICTURE HE SAW EACH MOMENT A GREATER RE...
# 6  arctic_a0139.wav  HE TOLD HIMSELF THAT AS HE WASHED HIMSELF AND ...
# 7  arctic_a0141.wav  IT SEEMS LIKE A STRANGE POINTING OF THE HAND O...
# 8  arctic_a0140.wav        ACCEPT A FATHER'S BLESSING AND WITH IT THIS
# 9  arctic_a0143.wav                    AH I HAD FORGOTTEN HE EXCLAIMED
#
#    emotion actor  gender clean_filename  \
# 0  neutral   clb  female          a0133
# 1  neutral   clb  female          a0132
# 2  neutral   clb  female          a0136
# 3  neutral   clb  female          a0137
# 4  neutral   clb  female          a0135
# 5  neutral   clb  female          a0138
# 6  neutral   clb  female          a0139
# 7  neutral   clb  female          a0141
# 8  neutral   clb  female          a0140
# 9  neutral   clb  female          a0143
#
#                                                label
# 0  Philip began to feel that he had foolishly ove...
# 1             A cry of joy burst from Philip's lips.
# 2  About him, everywhere, were the evidences of l...
# 3   Then he stepped back with a low cry of pleasure.
# 4  I am going to surprise father, and you will go...
# 5  In the picture he saw each moment a greater re...
# 6  He told himself that as he washed himself and ...
# 7  It seems like a strange pointing of the hand o...
# 8     Accept a father's blessing, and with it, this.
# 9                 Ah, I had forgotten, he exclaimed.

# %% [markdown]
# ## Confirm the first 5 characters of the auto transcription and label matches, or the last 5 characters of the auto transcription and label matches, if neither matches, manually investigate

# %% [markdown]
# ### check the first 5 characters

# %%
front_assertions = []

for i, row in clb.iterrows():
  if str(row['auto_transcription'])[:5].lower() == str(row['label'])[:5].lower():
    front_assertions.append('Y')
  else:
    front_assertions.append('N')

assert len(front_assertions) == len(clb)

front_assertions[:5]
# Out:
# ['Y', 'Y', 'Y', 'Y', 'Y']

# %%
clb['front_assertions'] = front_assertions

clb.head()
# Out:
#            filename                                 auto_transcription  \
# 0  arctic_a0133.wav  PHILIP BEGAN TO FEEL THAT HE HAD FOOLISHLY OVE...
# 1  arctic_a0132.wav             A CRY OF JOY BURST FROM PHILLIP'S LIPS
# 2  arctic_a0136.wav  ABOUT HIM EVERYWHERE WERE THE EVIDENCES OF LUX...
# 3  arctic_a0137.wav    THEN HE STEPPED BACK WITH A LOW CRY OF PLEASURE
# 4  arctic_a0135.wav  I AM GOING TO SURPRISE FATHER AND YOU WILL GO ...
#
#    emotion actor  gender clean_filename  \
# 0  neutral   clb  female          a0133
# 1  neutral   clb  female          a0132
# 2  neutral   clb  female          a0136
# 3  neutral   clb  female          a0137
# 4  neutral   clb  female          a0135
#
#                                                label front_assertions
# 0  Philip began to feel that he had foolishly ove...                Y
# 1             A cry of joy burst from Philip's lips.                Y
# 2  About him, everywhere, were the evidences of l...                Y
# 3   Then he stepped back with a low cry of pleasure.                Y
# 4  I am going to surprise father, and you will go...                Y

# %%
clb['front_assertions'].value_counts()
# Out:
# Y    1047
# N      85
# Name: front_assertions, dtype: int64

# %% [markdown]
# ### check the last 5 characters

# %%
back_assertions = []

for i, row in clb.iterrows():
  if str(row['auto_transcription'])[-5:].lower() == str(row['label']).replace('.','')[-5:].lower():
      back_assertions.append('Y')
  else:
    back_assertions.append('N')

assert len(back_assertions) == len(clb)

back_assertions[:5]
# Out:
# ['Y', 'Y', 'Y', 'Y', 'Y']

# %%
clb['back_assertions'] = back_assertions

clb.head()
# Out:
#            filename                                 auto_transcription  \
# 0  arctic_a0133.wav  PHILIP BEGAN TO FEEL THAT HE HAD FOOLISHLY OVE...
# 1  arctic_a0132.wav             A CRY OF JOY BURST FROM PHILLIP'S LIPS
# 2  arctic_a0136.wav  ABOUT HIM EVERYWHERE WERE THE EVIDENCES OF LUX...
# 3  arctic_a0137.wav    THEN HE STEPPED BACK WITH A LOW CRY OF PLEASURE
# 4  arctic_a0135.wav  I AM GOING TO SURPRISE FATHER AND YOU WILL GO ...
#
#    emotion actor  gender clean_filename  \
# 0  neutral   clb  female          a0133
# 1  neutral   clb  female          a0132
# 2  neutral   clb  female          a0136
# 3  neutral   clb  female          a0137
# 4  neutral   clb  female          a0135
#
#                                                label front_assertions  \
# 0  Philip began to feel that he had foolishly ove...                Y
# 1             A cry of joy burst from Philip's lips.                Y
# 2  About him, everywhere, were the evidences of l...                Y
# 3   Then he stepped back with a low cry of pleasure.                Y
# 4  I am going to surprise father, and you will go...                Y
#
#   back_assertions
# 0               Y
# 1               Y
# 2               Y
# 3               Y
# 4               Y

# %%
clb['back_assertions'].value_counts()
# Out:
# Y    1070
# N      62
# Name: back_assertions, dtype: int64

# %% [markdown]
# ### manually check instances where either front and back assertions failed

# %%
clb[(clb['front_assertions'] == 'N') | (clb['back_assertions'] == 'N')]
# Out:
#               filename                                 auto_transcription  \
# 5     arctic_a0138.wav  IN THE PICTURE HE SAW EACH MOMENT A GREATER RE...
# 9     arctic_a0143.wav                    AH I HAD FORGOTTEN HE EXCLAIMED
# 17    arctic_a0150.wav                         GOOD BYE PIERRE HE SHOUTED
# 20    arctic_a0153.wav  MCDUGAL TAPPED HIS FOREHEAD SUSPICIOUSLY WITH ...
# 32    arctic_a0164.wav  HE CAME FIRST A YEAR AGO AND REVEALED HIMSELF ...
# ...                ...                                                ...
# 1109  arctic_a0110.wav                       MUCH REPLIED JEAN AS TURSELY
# 1116  arctic_a0119.wav                 JEAN WAS TURNING THE BOW SHOREWARD
# 1117  arctic_a0120.wav  MY RIGHT FOOT FEELS LIKE THAT OF A CHINESE DEB...
# 1119  arctic_a0118.wav                PIERE OBEYS ME WHEN WE ARE TOGETHER
# 1128  arctic_a0131.wav  PROVIDENCE HAD DELIVERED HIM THROUGH THE MAILS...
#
#       emotion actor  gender clean_filename  \
# 5     neutral   clb  female          a0138
# 9     neutral   clb  female          a0143
# 17    neutral   clb  female          a0150
# 20    neutral   clb  female          a0153
# 32    neutral   clb  female          a0164
# ...       ...   ...     ...            ...
# 1109  neutral   clb  female          a0110
# 1116  neutral   clb  female          a0119
# 1117  neutral   clb  female          a0120
# 1119  neutral   clb  female          a0118
# 1128  neutral   clb  female          a0131
#
#                                                   label front_assertions  \
# 5     In the picture he saw each moment a greater re...                Y
# 9                    Ah, I had forgotten, he exclaimed.                N
# 17                         Goodbye, Pierre, he shouted.                N
# 20    MacDougall tapped his forehead suspiciously wi...                N
# 32    He came first a year ago, and revealed himself...                Y
# ...                                                 ...              ...
# 1109                  Much, replied Jeanne, as tersely.                N
# 1116              Jeanne was turning the bow shoreward.                N
# 1117  My right foot feels like that of a Chinese deb...                Y
# 1119              Pierre obeys me when we are together.                N
# 1128  Providence had delivered him through the maels...                Y
#
#      back_assertions
# 5                  N
# 9                  Y
# 17                 Y
# 20                 Y
# 32                 N
# ...              ...
# 1109               Y
# 1116               Y
# 1117               N
# 1119               Y
# 1128               N
#
# [143 rows x 9 columns]

# %% [markdown]
# Manually checked instances where either the front or the back assertions failed, confirmed no mis-matched instances

# %% [markdown]
# # Export the cleaned clb csv to be merged to the main csv

# %%
clb.drop(columns=['front_assertions', 'back_assertions'], inplace=True)

clb.head()
# Out:
#            filename                                 auto_transcription  \
# 0  arctic_a0133.wav  PHILIP BEGAN TO FEEL THAT HE HAD FOOLISHLY OVE...
# 1  arctic_a0132.wav             A CRY OF JOY BURST FROM PHILLIP'S LIPS
# 2  arctic_a0136.wav  ABOUT HIM EVERYWHERE WERE THE EVIDENCES OF LUX...
# 3  arctic_a0137.wav    THEN HE STEPPED BACK WITH A LOW CRY OF PLEASURE
# 4  arctic_a0135.wav  I AM GOING TO SURPRISE FATHER AND YOU WILL GO ...
#
#    emotion actor  gender clean_filename  \
# 0  neutral   clb  female          a0133
# 1  neutral   clb  female          a0132
# 2  neutral   clb  female          a0136
# 3  neutral   clb  female          a0137
# 4  neutral   clb  female          a0135
#
#                                                label
# 0  Philip began to feel that he had foolishly ove...
# 1             A cry of joy burst from Philip's lips.
# 2  About him, everywhere, were the evidences of l...
# 3   Then he stepped back with a low cry of pleasure.
# 4  I am going to surprise father, and you will go...

# %%
clb.to_csv('/content/drive/MyDrive/266/Data/Clean_Data/Arctic/clb.csv', index=False)
