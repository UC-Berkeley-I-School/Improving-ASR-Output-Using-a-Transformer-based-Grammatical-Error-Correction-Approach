# %% [markdown]
# # Import libraries

# %%
# drive access
from google.colab import drive
drive.mount('/content/drive')

# standard library
import numpy as np
import pandas as pd

# for audio
import librosa
from IPython.display import Audio
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Read the transcription csv

# %%
transcription = pd.read_csv('/content/drive/MyDrive/266/Data/Clean_Data/Arctic/transcription.csv')

transcription.head()
# Out:
#   filename                                      transcription
# 0    a0001    Author of the danger trail, Philip Steels, etc.
# 1    a0002  Not at this particular case, Tom, apologized W...
# 2    a0003  For the twentieth time that evening the two me...
# 3    a0004         Lord, but I'm glad to see you again, Phil.
# 4    a0005                            Will we ever forget it.

# %%
transcription.tail()
# Out:
#      filename                                      transcription
# 1127    b0535                       He read his fragments aloud.
# 1128    b0536                         Typhoid -- did I tell you.
# 1129    b0537                   But she had become an automaton.
# 1130    b0538      At the best, they were necessary accessories.
# 1131    b0539  You were making them talk shop, Ruth charged him.

# %% [markdown]
# # Clean rms csv

# %%
rms = pd.read_csv('/content/drive/MyDrive/266/Data/Clean_Data/Arctic/auto_transcription/rms.csv')

rms.head()
# Out:
#            filename                                 auto_transcription
# 0  arctic_a0133.wav  PHILIP BEGAN TO FEEL THAT HE HAD FOOLISHLY OVE...
# 1  arctic_a0135.wav  I AM GOING TO SURPRISE FATHER AND YOU WILL GO ...
# 2  arctic_a0134.wav                 HE OBEYED THE PRESSURE OF HER HAND
# 3  arctic_a0136.wav  ABOUT HIM EVERYWHERE WERE THE EVIDENCES OF LUX...
# 4  arctic_a0137.wav    THEN HE STEPPED BACK WITH A LOW CRY OF PLEASURE

# %%
rms['emotion'] = 'neutral'

rms.head()
# Out:
#            filename                                 auto_transcription  \
# 0  arctic_a0133.wav  PHILIP BEGAN TO FEEL THAT HE HAD FOOLISHLY OVE...
# 1  arctic_a0135.wav  I AM GOING TO SURPRISE FATHER AND YOU WILL GO ...
# 2  arctic_a0134.wav                 HE OBEYED THE PRESSURE OF HER HAND
# 3  arctic_a0136.wav  ABOUT HIM EVERYWHERE WERE THE EVIDENCES OF LUX...
# 4  arctic_a0137.wav    THEN HE STEPPED BACK WITH A LOW CRY OF PLEASURE
#
#    emotion
# 0  neutral
# 1  neutral
# 2  neutral
# 3  neutral
# 4  neutral

# %% [markdown]
# ### Add actor and gender attributes to the total csv

# %%
rms['actor'] = 'rms'
rms['gender'] = 'male'

rms.head()
# Out:
#            filename                                 auto_transcription  \
# 0  arctic_a0133.wav  PHILIP BEGAN TO FEEL THAT HE HAD FOOLISHLY OVE...
# 1  arctic_a0135.wav  I AM GOING TO SURPRISE FATHER AND YOU WILL GO ...
# 2  arctic_a0134.wav                 HE OBEYED THE PRESSURE OF HER HAND
# 3  arctic_a0136.wav  ABOUT HIM EVERYWHERE WERE THE EVIDENCES OF LUX...
# 4  arctic_a0137.wav    THEN HE STEPPED BACK WITH A LOW CRY OF PLEASURE
#
#    emotion actor gender
# 0  neutral   rms   male
# 1  neutral   rms   male
# 2  neutral   rms   male
# 3  neutral   rms   male
# 4  neutral   rms   male

# %% [markdown]
# ## Get the cleaned filenames

# %%
clean_filenames = []
for each in rms['filename']:
  clean_filenames.append(each.split('.')[0].split('_')[-1])

assert len(clean_filenames) == len(rms)

clean_filenames[:5]
# Out:
# ['a0133', 'a0135', 'a0134', 'a0136', 'a0137']

# %%
rms['clean_filename'] = clean_filenames

rms.head()
# Out:
#            filename                                 auto_transcription  \
# 0  arctic_a0133.wav  PHILIP BEGAN TO FEEL THAT HE HAD FOOLISHLY OVE...
# 1  arctic_a0135.wav  I AM GOING TO SURPRISE FATHER AND YOU WILL GO ...
# 2  arctic_a0134.wav                 HE OBEYED THE PRESSURE OF HER HAND
# 3  arctic_a0136.wav  ABOUT HIM EVERYWHERE WERE THE EVIDENCES OF LUX...
# 4  arctic_a0137.wav    THEN HE STEPPED BACK WITH A LOW CRY OF PLEASURE
#
#    emotion actor gender clean_filename
# 0  neutral   rms   male          a0133
# 1  neutral   rms   male          a0135
# 2  neutral   rms   male          a0134
# 3  neutral   rms   male          a0136
# 4  neutral   rms   male          a0137

# %% [markdown]
# ## Get the true transcriptions/labels based on cleaned filenames

# %%
labels = []

for row in rms['clean_filename']:
  labels.append(transcription[transcription['filename'] == row]['transcription'].item())

assert len(labels) == len(rms)

labels[:5]
# Out:
# ['Philip began to feel that he had foolishly overestimated his strength.',
#  'I am going to surprise father, and you will go with Pierre.',
#  'He obeyed the pressure of her hand.',
#  'About him, everywhere, were the evidences of luxury and of age.',
#  'Then he stepped back with a low cry of pleasure.']

# %%
rms['label'] = labels

rms.head(10)
# Out:
#            filename                                 auto_transcription  \
# 0  arctic_a0133.wav  PHILIP BEGAN TO FEEL THAT HE HAD FOOLISHLY OVE...
# 1  arctic_a0135.wav  I AM GOING TO SURPRISE FATHER AND YOU WILL GO ...
# 2  arctic_a0134.wav                 HE OBEYED THE PRESSURE OF HER HAND
# 3  arctic_a0136.wav  ABOUT HIM EVERYWHERE WERE THE EVIDENCES OF LUX...
# 4  arctic_a0137.wav    THEN HE STEPPED BACK WITH A LOW CRY OF PLEASURE
# 5  arctic_a0138.wav  IN THE PICTURE HE SAW EACH MOMENT A GREATER RE...
# 6  arctic_a0140.wav        ACCEPT A FATHER'S BLESSING AND WITH IT THIS
# 7  arctic_a0139.wav  HE TOLD HIMSELF THAT AS HE WASHED HIMSELF AND ...
# 8  arctic_a0141.wav  IT SEEMS LIKE A STRANGE POINTING OF THE HAND O...
# 9  arctic_a0143.wav                    AH I HAD FORGOTTEN HE EXCLAIMED
#
#    emotion actor gender clean_filename  \
# 0  neutral   rms   male          a0133
# 1  neutral   rms   male          a0135
# 2  neutral   rms   male          a0134
# 3  neutral   rms   male          a0136
# 4  neutral   rms   male          a0137
# 5  neutral   rms   male          a0138
# 6  neutral   rms   male          a0140
# 7  neutral   rms   male          a0139
# 8  neutral   rms   male          a0141
# 9  neutral   rms   male          a0143
#
#                                                label
# 0  Philip began to feel that he had foolishly ove...
# 1  I am going to surprise father, and you will go...
# 2                He obeyed the pressure of her hand.
# 3  About him, everywhere, were the evidences of l...
# 4   Then he stepped back with a low cry of pleasure.
# 5  In the picture he saw each moment a greater re...
# 6     Accept a father's blessing, and with it, this.
# 7  He told himself that as he washed himself and ...
# 8  It seems like a strange pointing of the hand o...
# 9                 Ah, I had forgotten, he exclaimed.

# %% [markdown]
# ## Confirm the first 5 characters of the auto transcription and label matches, or the last 5 characters of the auto transcription and label matches, if neither matches, manually investigate

# %% [markdown]
# ### check the first 5 characters

# %%
front_assertions = []

for i, row in rms.iterrows():
  if str(row['auto_transcription'])[:5].lower() == str(row['label'])[:5].lower():
    front_assertions.append('Y')
  else:
    front_assertions.append('N')

assert len(front_assertions) == len(rms)

front_assertions[:5]
# Out:
# ['Y', 'Y', 'Y', 'Y', 'Y']

# %%
rms['front_assertions'] = front_assertions

rms.head()
# Out:
#            filename                                 auto_transcription  \
# 0  arctic_a0133.wav  PHILIP BEGAN TO FEEL THAT HE HAD FOOLISHLY OVE...
# 1  arctic_a0135.wav  I AM GOING TO SURPRISE FATHER AND YOU WILL GO ...
# 2  arctic_a0134.wav                 HE OBEYED THE PRESSURE OF HER HAND
# 3  arctic_a0136.wav  ABOUT HIM EVERYWHERE WERE THE EVIDENCES OF LUX...
# 4  arctic_a0137.wav    THEN HE STEPPED BACK WITH A LOW CRY OF PLEASURE
#
#    emotion actor gender clean_filename  \
# 0  neutral   rms   male          a0133
# 1  neutral   rms   male          a0135
# 2  neutral   rms   male          a0134
# 3  neutral   rms   male          a0136
# 4  neutral   rms   male          a0137
#
#                                                label front_assertions
# 0  Philip began to feel that he had foolishly ove...                Y
# 1  I am going to surprise father, and you will go...                Y
# 2                He obeyed the pressure of her hand.                Y
# 3  About him, everywhere, were the evidences of l...                Y
# 4   Then he stepped back with a low cry of pleasure.                Y

# %%
rms['front_assertions'].value_counts()
# Out:
# Y    1033
# N      99
# Name: front_assertions, dtype: int64

# %% [markdown]
# ### check the last 5 characters

# %%
back_assertions = []

for i, row in rms.iterrows():
  if str(row['auto_transcription'])[-5:].lower() == str(row['label']).replace('.','')[-5:].lower():
      back_assertions.append('Y')
  else:
    back_assertions.append('N')

assert len(back_assertions) == len(rms)

back_assertions[:5]
# Out:
# ['Y', 'Y', 'Y', 'Y', 'Y']

# %%
rms['back_assertions'] = back_assertions

rms.head()
# Out:
#            filename                                 auto_transcription  \
# 0  arctic_a0133.wav  PHILIP BEGAN TO FEEL THAT HE HAD FOOLISHLY OVE...
# 1  arctic_a0135.wav  I AM GOING TO SURPRISE FATHER AND YOU WILL GO ...
# 2  arctic_a0134.wav                 HE OBEYED THE PRESSURE OF HER HAND
# 3  arctic_a0136.wav  ABOUT HIM EVERYWHERE WERE THE EVIDENCES OF LUX...
# 4  arctic_a0137.wav    THEN HE STEPPED BACK WITH A LOW CRY OF PLEASURE
#
#    emotion actor gender clean_filename  \
# 0  neutral   rms   male          a0133
# 1  neutral   rms   male          a0135
# 2  neutral   rms   male          a0134
# 3  neutral   rms   male          a0136
# 4  neutral   rms   male          a0137
#
#                                                label front_assertions  \
# 0  Philip began to feel that he had foolishly ove...                Y
# 1  I am going to surprise father, and you will go...                Y
# 2                He obeyed the pressure of her hand.                Y
# 3  About him, everywhere, were the evidences of l...                Y
# 4   Then he stepped back with a low cry of pleasure.                Y
#
#   back_assertions
# 0               Y
# 1               Y
# 2               Y
# 3               Y
# 4               Y

# %%
rms['back_assertions'].value_counts()
# Out:
# Y    1068
# N      64
# Name: back_assertions, dtype: int64

# %% [markdown]
# ### manually check instances where either front and back assertions failed

# %%
rms[(rms['front_assertions'] == 'N') | (rms['back_assertions'] == 'N')]
# Out:
#               filename                                 auto_transcription  \
# 5     arctic_a0138.wav  IN THE PICTURE HE SAW EACH MOMENT A GREATER RE...
# 9     arctic_a0143.wav                    AH I HAD FORGOTTEN HE EXCLAIMED
# 17    arctic_a0150.wav                         GOOD BYE PIERRE HE SHOUTED
# 20    arctic_a0153.wav  MIC DUGEL TAPPED HIS FOREHEAD SUSPICIOUSLY WIT...
# 31    arctic_a0164.wav  HE CAME FIRST A YEAR AGO AND REVEALED HIMSELF ...
# ...                ...                                                ...
# 1109  arctic_a0110.wav                       MUCH REPLIED GEAN ESTURSELEY
# 1113  arctic_a0114.wav       HER WORDS SENT A STRANGE CHILL THROUGH FILIP
# 1118  arctic_a0119.wav                 JEAN WAS TURNING THE BOW SHOREWARD
# 1120  arctic_a0120.wav  MY RIGHT FOOT FEELS LIKE THAT OF A CHINESE DEB...
# 1129  arctic_a0130.wav                           SHE WAS HIS NOW FOR EVER
#
#       emotion actor gender clean_filename  \
# 5     neutral   rms   male          a0138
# 9     neutral   rms   male          a0143
# 17    neutral   rms   male          a0150
# 20    neutral   rms   male          a0153
# 31    neutral   rms   male          a0164
# ...       ...   ...    ...            ...
# 1109  neutral   rms   male          a0110
# 1113  neutral   rms   male          a0114
# 1118  neutral   rms   male          a0119
# 1120  neutral   rms   male          a0120
# 1129  neutral   rms   male          a0130
#
#                                                   label front_assertions  \
# 5     In the picture he saw each moment a greater re...                Y
# 9                    Ah, I had forgotten, he exclaimed.                N
# 17                         Goodbye, Pierre, he shouted.                N
# 20    MacDougall tapped his forehead suspiciously wi...                N
# 31    He came first a year ago, and revealed himself...                Y
# ...                                                 ...              ...
# 1109                  Much, replied Jeanne, as tersely.                N
# 1113     Her words sent a strange chill through Philip.                Y
# 1118              Jeanne was turning the bow shoreward.                N
# 1120  My right foot feels like that of a Chinese deb...                Y
# 1129                          She was his now, forever.                Y
#
#      back_assertions
# 5                  N
# 9                  Y
# 17                 Y
# 20                 Y
# 31                 N
# ...              ...
# 1109               N
# 1113               N
# 1118               Y
# 1120               N
# 1129               N
#
# [154 rows x 9 columns]

# %% [markdown]
# Manually checked instances where either the front or the back assertions failed, confirmed no mis-matched instances

# %% [markdown]
# # Export the cleaned rms csv to be merged to the main csv

# %%
rms.drop(columns=['front_assertions', 'back_assertions'], inplace=True)

rms.head()
# Out:
#            filename                                 auto_transcription  \
# 0  arctic_a0133.wav  PHILIP BEGAN TO FEEL THAT HE HAD FOOLISHLY OVE...
# 1  arctic_a0135.wav  I AM GOING TO SURPRISE FATHER AND YOU WILL GO ...
# 2  arctic_a0134.wav                 HE OBEYED THE PRESSURE OF HER HAND
# 3  arctic_a0136.wav  ABOUT HIM EVERYWHERE WERE THE EVIDENCES OF LUX...
# 4  arctic_a0137.wav    THEN HE STEPPED BACK WITH A LOW CRY OF PLEASURE
#
#    emotion actor gender clean_filename  \
# 0  neutral   rms   male          a0133
# 1  neutral   rms   male          a0135
# 2  neutral   rms   male          a0134
# 3  neutral   rms   male          a0136
# 4  neutral   rms   male          a0137
#
#                                                label
# 0  Philip began to feel that he had foolishly ove...
# 1  I am going to surprise father, and you will go...
# 2                He obeyed the pressure of her hand.
# 3  About him, everywhere, were the evidences of l...
# 4   Then he stepped back with a low cry of pleasure.

# %%
rms.to_csv('/content/drive/MyDrive/266/Data/Clean_Data/Arctic/rms.csv', index=False)
