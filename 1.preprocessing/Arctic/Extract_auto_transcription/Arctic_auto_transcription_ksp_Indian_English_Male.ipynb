# %% [markdown]
# # Import libraries

# %%
# drive access
from google.colab import drive
drive.mount('/content/drive')

# standard library
import numpy as np
import pandas as pd

# for audio
import librosa
from IPython.display import Audio

# for file streaming
import os

# for model
# !pip install transformers
from transformers import Wav2Vec2Processor, Wav2Vec2ForCTC
import torch
# Out:
# Mounted at /content/drive
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 44.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.0/295.0 kB 18.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 91.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 57.4 MB/s eta 0:00:00
# ...

# %%
# load model and tokenizer
processor = Wav2Vec2Processor.from_pretrained("facebook/wav2vec2-base-960h")
model = Wav2Vec2ForCTC.from_pretrained("facebook/wav2vec2-base-960h")
# Out:
# ...
# Some weights of Wav2Vec2ForCTC were not initialized from the model checkpoint at facebook/wav2vec2-base-960h and are newly initialized: ['wav2vec2.masked_spec_embed']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %% [markdown]
# # Load examples from ksp

# %%
audio, _ = librosa.load('/content/drive/MyDrive/266/Data/Raw_Data/Arctic/cmu_us_ksp_arctic/wav/arctic_b0539.wav', sr=16000)

# %%
Audio(audio, rate=16000)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
audio, _ = librosa.load('/content/drive/MyDrive/266/Data/Raw_Data/Arctic/cmu_us_ksp_arctic/wav/arctic_b0538.wav', sr=16000)

# %%
Audio(audio, rate=16000)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# # get the files from bea_Amused folder & create auto transcription using wav2vec

# %%
audio_filename = os.listdir('/content/drive/MyDrive/266/Data/Raw_Data/Arctic/cmu_us_ksp_arctic/wav')

audio_filename
# Out:
# ['arctic_a0131.wav',
#  'arctic_a0127.wav',
#  'arctic_a0086.wav',
#  'arctic_a0118.wav',
#  'arctic_a0088.wav',
#  'arctic_a0129.wav',
#  'arctic_a0158.wav',
#  'arctic_a0195.wav',
#  'arctic_a0177.wav',
#  'arctic_a0196.wav',
#  'arctic_a0182.wav',
#  'arctic_a0208.wav',
#  'arctic_a0175.wav',
#  'arctic_a0159.wav',
#  'arctic_a0167.wav',
#  'arctic_a0152.wav',
#  'arctic_a0170.wav',
#  'arctic_a0147.wav',
#  'arctic_a0214.wav',
#  'arctic_a0190.wav',
#  'arctic_a0200.wav',
#  'arctic_a0216.wav',
#  'arctic_a0166.wav',
#  'arctic_a0183.wav',
#  'arctic_a0189.wav',
#  'arctic_a0198.wav',
#  'arctic_a0160.wav',
#  'arctic_a0201.wav',
#  'arctic_a0209.wav',
#  'arctic_a0181.wav',
#  'arctic_a0168.wav',
#  'arctic_a0185.wav',
#  'arctic_a0178.wav',
#  'arctic_a0171.wav',
#  'arctic_a0156.wav',
#  'arctic_a0145.wav',
#  'arctic_a0205.wav',
#  'arctic_a0207.wav',
#  'arctic_a0146.wav',
#  'arctic_a0173.wav',
#  'arctic_a0187.wav',
#  'arctic_a0191.wav',
#  'arctic_a0194.wav',
# ...

# %%
audio_df = pd.DataFrame()

audio_df['filename'] = audio_filename

audio_df.head()
# Out:
#            filename
# 0  arctic_a0131.wav
# 1  arctic_a0127.wav
# 2  arctic_a0086.wav
# 3  arctic_a0118.wav
# 4  arctic_a0088.wav

# %%
auto_transcription = []

for filename in audio_df['filename']:
  audio, _ = librosa.load(f'/content/drive/MyDrive/266/Data/Raw_Data/Arctic/cmu_us_ksp_arctic/wav/{filename}', sr=16000)
  input_value = processor(audio, return_tensors="pt", padding="longest", sampling_rate=16000).input_values
  predicted_id = torch.argmax(model(input_value).logits, dim=-1)
  transcription = processor.batch_decode(predicted_id)
  auto_transcription.append(transcription[0])
  del audio, input_value, predicted_id, transcription

auto_transcription
# Out:
# ['PROVIDENCE HAD DELIVERED HIM TO THE MAILSTROM',
#  'IT WAS A TEMPTATION BUT HE ASSISTED IT',
#  'DEATH HAD COME WITH DERIBULSRANES',
#  'BEERD OBEYS ME WHEN WE ARE TOGETHER',
#  'HE MADE SURE THAT THE MAGAZINE WAS LOADED AND RESUMED HIS PADDLING',
#  'HER FACE WAS AGAINST HIS BREAST',
#  'DOES THAT LOK GOOD',
#  'BUT THE STRANGE THING HAPPENED',
#  'SHE HAD BEEN THROLY AND EFFICIENTLY MILD',
#  'HE BEGAN TO FOLLOW THE FOOTPRINTS OF THE DOG',
#  "THIS TIME HE DIDN'T YAP FOR MERCY",
#  'YOUTH HAD COME BACK TO HER FREED FROM THE YOKE OF OPPRESSION',
#  'DOWN THERE THE EARTH WAS ALREADY SFILLING WITH LIFE',
#  'THEY LOOKED AS THOUGH HE HAD BEEN DRUMMING A PIANO ALL HIS LIFE',
#  'I WAS NEAR THE CABIN AND SAW YOU',
#  'PHILIP TRUST HIMSELF AGAINST IT AND ENTERED',
#  'THERE WAS NONE OF THE GY OF MEETING IN HIS FACE',
#  'A WOMENT BEFORE HE WAS INTOXICATED BY A JY THAT WAS ALMOST MADNESS',
#  'BESIDES HE WAS PAID ONE CAISE OF TOBACCO ER HEAD',
# ...

# %% [markdown]
# confirm all files from bea_amused have been auto transcribed & add to the df

# %%
assert len(audio_df) == len(auto_transcription)

# %%
audio_df['auto_transcription'] = auto_transcription

# %%
audio_df.head()
# Out:
#            filename                                 auto_transcription
# 0  arctic_a0131.wav      PROVIDENCE HAD DELIVERED HIM TO THE MAILSTROM
# 1  arctic_a0127.wav             IT WAS A TEMPTATION BUT HE ASSISTED IT
# 2  arctic_a0086.wav                  DEATH HAD COME WITH DERIBULSRANES
# 3  arctic_a0118.wav                BEERD OBEYS ME WHEN WE ARE TOGETHER
# 4  arctic_a0088.wav  HE MADE SURE THAT THE MAGAZINE WAS LOADED AND ...

# %% [markdown]
# take a look at one example

# %%
example = audio_df['filename'].iloc[0]
audio, _ = librosa.load(f'/content/drive/MyDrive/266/Data/Raw_Data/Arctic/cmu_us_ksp_arctic/wav/{example}', sr=16000)

# %%
Audio(audio, rate=16000)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
audio_df['auto_transcription'].iloc[0]
# Out:
# 'PROVIDENCE HAD DELIVERED HIM TO THE MAILSTROM'

# %% [markdown]
# save the df to csv file for future use

# %%
audio_df.to_csv('/content/drive/MyDrive/266/Data/Clean_Data/Arctic/auto_transcription/ksp.csv', index=False)

# %%
check = pd.read_csv('/content/drive/MyDrive/266/Data/Clean_Data/Arctic/auto_transcription/ksp.csv')

check.head()
# Out:
#            filename                                 auto_transcription
# 0  arctic_a0131.wav      PROVIDENCE HAD DELIVERED HIM TO THE MAILSTROM
# 1  arctic_a0127.wav             IT WAS A TEMPTATION BUT HE ASSISTED IT
# 2  arctic_a0086.wav                  DEATH HAD COME WITH DERIBULSRANES
# 3  arctic_a0118.wav                BEERD OBEYS ME WHEN WE ARE TOGETHER
# 4  arctic_a0088.wav  HE MADE SURE THAT THE MAGAZINE WAS LOADED AND ...
