# %% [markdown]
# # Import libraries

# %%
# drive access
from google.colab import drive
drive.mount('/content/drive')

# standard library
import numpy as np
import pandas as pd

# for audio
import librosa
from IPython.display import Audio

# for file streaming
import os

# for model
# !pip install transformers
from transformers import Wav2Vec2Processor, Wav2Vec2ForCTC
import torch
# Out:
# Mounted at /content/drive
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 24.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.0/295.0 kB 23.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 38.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 50.6 MB/s eta 0:00:00
# ...

# %%
# load model and tokenizer
processor = Wav2Vec2Processor.from_pretrained("facebook/wav2vec2-base-960h")
model = Wav2Vec2ForCTC.from_pretrained("facebook/wav2vec2-base-960h")
# Out:
# ...
# Some weights of Wav2Vec2ForCTC were not initialized from the model checkpoint at facebook/wav2vec2-base-960h and are newly initialized: ['wav2vec2.masked_spec_embed']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %% [markdown]
# # Load examples from clb

# %%
audio, _ = librosa.load('/content/drive/MyDrive/266/Data/Raw_Data/Arctic/cmu_us_clb_arctic/wav/arctic_b0539.wav', sr=16000)

# %%
Audio(audio, rate=16000)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
audio, _ = librosa.load('/content/drive/MyDrive/266/Data/Raw_Data/Arctic/cmu_us_clb_arctic/wav/arctic_b0538.wav', sr=16000)

# %%
Audio(audio, rate=16000)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# # get the files from bea_Amused folder & create auto transcription using wav2vec

# %%
audio_filename = os.listdir('/content/drive/MyDrive/266/Data/Raw_Data/Arctic/cmu_us_clb_arctic/wav')

audio_filename
# Out:
# ['arctic_a0133.wav',
#  'arctic_a0132.wav',
#  'arctic_a0136.wav',
#  'arctic_a0137.wav',
#  'arctic_a0135.wav',
#  'arctic_a0138.wav',
#  'arctic_a0139.wav',
#  'arctic_a0141.wav',
#  'arctic_a0140.wav',
#  'arctic_a0143.wav',
#  'arctic_a0142.wav',
#  'arctic_a0146.wav',
#  'arctic_a0145.wav',
#  'arctic_a0144.wav',
#  'arctic_a0147.wav',
#  'arctic_a0148.wav',
#  'arctic_a0152.wav',
#  'arctic_a0150.wav',
#  'arctic_a0151.wav',
#  'arctic_a0149.wav',
#  'arctic_a0153.wav',
#  'arctic_a0154.wav',
#  'arctic_a0156.wav',
#  'arctic_a0155.wav',
#  'arctic_a0158.wav',
#  'arctic_a0157.wav',
#  'arctic_a0160.wav',
#  'arctic_a0159.wav',
#  'arctic_a0163.wav',
#  'arctic_a0162.wav',
#  'arctic_a0161.wav',
#  'arctic_a0165.wav',
#  'arctic_a0164.wav',
#  'arctic_a0166.wav',
#  'arctic_a0167.wav',
#  'arctic_a0168.wav',
#  'arctic_a0169.wav',
#  'arctic_a0171.wav',
#  'arctic_a0170.wav',
#  'arctic_a0175.wav',
#  'arctic_a0173.wav',
#  'arctic_a0174.wav',
#  'arctic_a0172.wav',
# ...

# %%
audio_df = pd.DataFrame()

audio_df['filename'] = audio_filename

audio_df.head()
# Out:
#            filename
# 0  arctic_a0133.wav
# 1  arctic_a0132.wav
# 2  arctic_a0136.wav
# 3  arctic_a0137.wav
# 4  arctic_a0135.wav

# %%
auto_transcription = []

for filename in audio_df['filename']:
  audio, _ = librosa.load(f'/content/drive/MyDrive/266/Data/Raw_Data/Arctic/cmu_us_clb_arctic/wav/{filename}', sr=16000)
  input_value = processor(audio, return_tensors="pt", padding="longest", sampling_rate=16000).input_values
  predicted_id = torch.argmax(model(input_value).logits, dim=-1)
  transcription = processor.batch_decode(predicted_id)
  auto_transcription.append(transcription[0])
  del audio, input_value, predicted_id, transcription

auto_transcription
# Out:
# ['PHILIP BEGAN TO FEEL THAT HE HAD FOOLISHLY OVERESTIMATED HIS STRENGTH',
#  "A CRY OF JOY BURST FROM PHILLIP'S LIPS",
#  'ABOUT HIM EVERYWHERE WERE THE EVIDENCES OF LUXURY AND OF AGE',
#  'THEN HE STEPPED BACK WITH A LOW CRY OF PLEASURE',
#  'I AM GOING TO SURPRISE FATHER AND YOU WILL GO WITH PIERRE',
#  'IN THE PICTURE HE SAW EACH MOMENT A GREATER RESEMBLANCE TO JEAN',
#  'HE TOLD HIMSELF THAT AS HE WASHED HIMSELF AND GROOMED HIS DISHEVELLED CLOTHES',
#  'IT SEEMS LIKE A STRANGE POINTING OF THE HAND OF GOD',
#  "ACCEPT A FATHER'S BLESSING AND WITH IT THIS",
#  'AH I HAD FORGOTTEN HE EXCLAIMED',
#  'SUCH THINGS HAD OCCURRED BEFORE HE TOLD PHILIP',
#  'OF COURSE THAT IS UNINTERESTING SHE CONTINUED',
#  'I HAVE TO BE CAREFUL OF THEM AS THEY TEAR VERY EASILY',
#  'BUT THERE IS SOMETHING EVEN MORE STARTLING THAN THIS RESEMBLANCE',
#  'A MOMENT BEFORE HE WAS INTOXICATED BY A JOY THAT WAS ALMOST MADNESS',
#  'NOW THESE THINGS HAD BEEN STRUCK DEAD WITHIN HIM',
# ...

# %% [markdown]
# confirm all files from bea_amused have been auto transcribed & add to the df

# %%
assert len(audio_df) == len(auto_transcription)

# %%
audio_df['auto_transcription'] = auto_transcription

# %%
audio_df.head()
# Out:
#            filename                                 auto_transcription
# 0  arctic_a0133.wav  PHILIP BEGAN TO FEEL THAT HE HAD FOOLISHLY OVE...
# 1  arctic_a0132.wav             A CRY OF JOY BURST FROM PHILLIP'S LIPS
# 2  arctic_a0136.wav  ABOUT HIM EVERYWHERE WERE THE EVIDENCES OF LUX...
# 3  arctic_a0137.wav    THEN HE STEPPED BACK WITH A LOW CRY OF PLEASURE
# 4  arctic_a0135.wav  I AM GOING TO SURPRISE FATHER AND YOU WILL GO ...

# %% [markdown]
# take a look at one example

# %%
example = audio_df['filename'].iloc[0]
audio, _ = librosa.load(f'/content/drive/MyDrive/266/Data/Raw_Data/Arctic/cmu_us_clb_arctic/wav/{example}', sr=16000)

# %%
Audio(audio, rate=16000)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
audio_df['auto_transcription'].iloc[0]
# Out:
# 'PHILIP BEGAN TO FEEL THAT HE HAD FOOLISHLY OVERESTIMATED HIS STRENGTH'

# %% [markdown]
# save the df to csv file for future use

# %%
audio_df.to_csv('/content/drive/MyDrive/266/Data/Clean_Data/Arctic/auto_transcription/clb.csv', index=False)

# %%
check = pd.read_csv('/content/drive/MyDrive/266/Data/Clean_Data/Arctic/auto_transcription/clb.csv')

check.head()
# Out:
#            filename                                 auto_transcription
# 0  arctic_a0133.wav  PHILIP BEGAN TO FEEL THAT HE HAD FOOLISHLY OVE...
# 1  arctic_a0132.wav             A CRY OF JOY BURST FROM PHILLIP'S LIPS
# 2  arctic_a0136.wav  ABOUT HIM EVERYWHERE WERE THE EVIDENCES OF LUX...
# 3  arctic_a0137.wav    THEN HE STEPPED BACK WITH A LOW CRY OF PLEASURE
# 4  arctic_a0135.wav  I AM GOING TO SURPRISE FATHER AND YOU WILL GO ...
